# %%
import pandas as pd

# %%
df = pd.read_csv('reviews.csv')

# %%
reviews_non_null_unique = df[df['id'].notnull()].drop_duplicates()

# %%
reviews_non_null_unique
# Out:
#                   id                                      title  \
# 0     R1VPOIOYD7VTB4  It will (kinda) work if you help it along
# 1     R2PXGDP7LLUQZ9           The Inbred 4th Cousin of iRoomba
# 2     R39UW33LNX7Y4Y           Better than new version for hair
# 3     R1KCWCARGBP5IH                         Wouldn't buy again
# 4      RGHFB9XYII9YN                               Good product
# 5      RB5PWJSAZC7FK                                 Works well
# 6     R1VYX4KK6R8UF0                            Stopped working
# 7     R38UVL2FJ8C9GA                      Great while it lasted
# 1032   R1RF6ZQB0IA07                     A glitch in the Matrix
# 1033  R3B2GF6D66T6NM   Out of the box it was giving me an error
# 1034   RO6QX41JFR1OI                 STOP WORING AFTER 2 MONTHS
# 1035  R2T03ZMNX28KUH                    It is not pet friendly.
# 1036   R1IC3FD5HPQ97                      STILL WORKING SO WELL
# 1037  R1E8RTRZ5Y09XE                    Fell apart after 1 year
#
# ...

# %%
reviews_non_null_unique.to_csv('unique_reviews.csv', index=False, header=True)
